# %% [markdown]
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
#
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rf-detr/charts.png)
#
# RF-DETR is the first real-time model to exceed 60 AP on the [Microsoft COCO benchmark](https://cocodataset.org/#home) alongside competitive performance at base sizes. It also achieves state-of-the-art performance on [RF100-VL](https://github.com/roboflow/rf100-vl), an object detection benchmark that measures model domain adaptability to real world problems. RF-DETR is comparable speed to current real-time objection models.
#
# ![rf-detr-coco-results-2](https://media.roboflow.com/rf-detr/example_grid.png)
#
# RF-DETR is small enough to run on the edge, making it an ideal model for deployments that need both strong accuracy and real-time performance.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Open your [`HuggingFace Settings`](https://huggingface.co/settings) page. Click `Access Tokens` then `New Token` to generate new token.
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store HuggingFace Access Token under the name `HF_TOKEN`.
#     - Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Apr 10 07:44:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -q rfdetr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 8.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 98.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 87.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.9/354.9 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.7 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ## Download dataset from Provided Links or of any Choice

# %%
from roboflow import download_dataset
from roboflow import Roboflow
rf = Roboflow(api_key="NlJjJc95VvzyJVlw6zNd")
project = rf.workspace("objdet-odjxg").project("fractlas3")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Fractlas3-1 to coco:: 100%|██████████| 14773/14773 [00:00<00:00, 32122.12it/s]
# Extracting Dataset Version Zip to Fractlas3-1 in coco:: 100%|██████████| 710/710 [00:00<00:00, 8548.72it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.
#
# ### Train with multiple GPUs
#
# You can fine-tune RF-DETR on multiple GPUs using PyTorch’s Distributed Data Parallel (DDP). Create a `main.py` script that initializes your model and calls `.train()` as usual than run it in terminal.
#
# ```bash
# python -m torch.distributed.launch \
#     --nproc_per_node=8 \
#     --use_env \
#     main.py
# ```
#
# Replace `8` in the `--nproc_per_node argument` with the number of GPUs you want to use. This approach creates one training process per GPU and splits the workload automatically. Note that your effective batch size is multiplied by the number of GPUs, so you may need to adjust your `batch_size` and `grad_accum_steps` to maintain the same overall batch size.

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()
history = []

def callback2(data):
    history.append(data)

model.callbacks["on_fit_epoch_end"].append(callback2)

model.train(dataset_dir=dataset.location, epochs=15, batch_size=4, grad_accum_steps=4, lr=1e-4)
# Out:
# rf-detr-base.pth: 100%|██████████| 355M/355M [00:04<00:00, 84.0MiB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 2 classes
# reinitializing your detection head with 2 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=4, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=15, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/Fractlas3-1', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=560, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, tensorboard=True, wandb=False, project=None, run=None, class_names=['fractured'], distributed=False)
# number of params: 31854308
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 30
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
# Epoch: [0]  [ 0/30]  eta: 0:05:25  lr: 0.000100  class_error: 89.74  loss: 19.3906 (19.3906)  loss_ce: 0.3824 (0.3824)  loss_bbox: 1.7051 (1.7051)  loss_giou: 1.9909 (1.9909)  loss_ce_0: 0.2355 (0.2355)  loss_bbox_0: 2.5364 (2.5364)  loss_giou_0: 2.3953 (2.3953)  loss_ce_1: 0.3596 (0.3596)  loss_bbox_1: 1.8115 (1.8115)  loss_giou_1: 2.0886 (2.0886)  loss_ce_enc: 0.2234 (0.2234)  loss_bbox_enc: 3.2249 (3.2249)  loss_giou_enc: 2.4370 (2.4370)  loss_ce_unscaled: 0.3824 (0.3824)  class_error_unscaled: 89.7436 (89.7436)  loss_bbox_unscaled: 0.3410 (0.3410)  loss_giou_unscaled: 0.9954 (0.9954)  cardinality_error_unscaled: 2585.7500 (2585.7500)  loss_ce_0_unscaled: 0.2355 (0.2355)  loss_bbox_0_unscaled: 0.5073 (0.5073)  loss_giou_0_unscaled: 1.1976 (1.1976)  cardinality_error_0_unscaled: 1423.7500 (1423.7500)  loss_ce_1_unscaled: 0.3596 (0.3596)  loss_bbox_1_unscaled: 0.3623 (0.3623)  loss_giou_1_unscaled: 1.0443 (1.0443)  cardinality_error_1_unscaled: 1718.0000 (1718.0000)  loss_ce_enc_unscaled: 0.2234 (0.2234)  loss_bbox_enc_unscaled: 0.6450 (0.6450)  loss_giou_enc_unscaled: 1.2185 (1.2185)  cardinality_error_enc_unscaled: 1675.0000 (1675.0000)  time: 10.8567  data: 1.3925  max mem: 8992
# Epoch: [0]  [10/30]  eta: 0:02:24  lr: 0.000100  class_error: 15.38  loss: 15.5340 (15.6609)  loss_ce: 0.4020 (0.4374)  loss_bbox: 1.2043 (1.2418)  loss_giou: 2.0322 (2.0085)  loss_ce_0: 0.3894 (0.3914)  loss_bbox_0: 1.2895 (1.3955)  loss_giou_0: 2.1751 (2.1495)  loss_ce_1: 0.4074 (0.4332)  loss_bbox_1: 1.1744 (1.2603)  loss_giou_1: 2.0886 (2.0129)  loss_ce_enc: 0.3237 (0.3146)  loss_bbox_enc: 1.4471 (1.7028)  loss_giou_enc: 2.3431 (2.3130)  loss_ce_unscaled: 0.4020 (0.4374)  class_error_unscaled: 62.8205 (55.3730)  loss_bbox_unscaled: 0.2409 (0.2484)  loss_giou_unscaled: 1.0161 (1.0042)  cardinality_error_unscaled: 2145.5000 (1812.6136)  loss_ce_0_unscaled: 0.3894 (0.3914)  loss_bbox_0_unscaled: 0.2579 (0.2791)  loss_giou_0_unscaled: 1.0876 (1.0748)  cardinality_error_0_unscaled: 2306.2500 (1961.5682)  loss_ce_1_unscaled: 0.4074 (0.4332)  loss_bbox_1_unscaled: 0.2349 (0.2521)  loss_giou_1_unscaled: 1.0443 (1.0064)  cardinality_error_1_unscaled: 2925.7500 (2726.2500)  loss_ce_enc_unscaled: 0.3237 (0.3146)  loss_bbox_enc_unscaled: 0.2894 (0.3406)  loss_giou_enc_unscaled: 1.1716 (1.1565)  cardinality_error_enc_unscaled: 1517.7500 (1526.4318)  time: 7.2135  data: 0.1667  max mem: 9227
# Epoch: [0]  [20/30]  eta: 0:01:11  lr: 0.000100  class_error: 0.00  loss: 13.8282 (14.3775)  loss_ce: 0.5731 (0.5506)  loss_bbox: 1.0037 (1.0712)  loss_giou: 1.7400 (1.8067)  loss_ce_0: 0.5102 (0.5087)  loss_bbox_0: 1.0732 (1.1702)  loss_giou_0: 1.8675 (1.9133)  loss_ce_1: 0.5547 (0.5485)  loss_bbox_1: 0.9956 (1.0746)  loss_giou_1: 1.7448 (1.8029)  loss_ce_enc: 0.4009 (0.4096)  loss_bbox_enc: 1.2655 (1.4343)  loss_giou_enc: 2.0391 (2.0869)  loss_ce_unscaled: 0.5731 (0.5506)  class_error_unscaled: 3.8462 (29.2491)  loss_bbox_unscaled: 0.2007 (0.2142)  loss_giou_unscaled: 0.8700 (0.9034)  cardinality_error_unscaled: 112.7500 (965.2381)  loss_ce_0_unscaled: 0.5102 (0.5087)  loss_bbox_0_unscaled: 0.2146 (0.2340)  loss_giou_0_unscaled: 0.9337 (0.9566)  cardinality_error_0_unscaled: 358.5000 (1085.1310)  loss_ce_1_unscaled: 0.5547 (0.5485)  loss_bbox_1_unscaled: 0.1991 (0.2149)  loss_giou_1_unscaled: 0.8724 (0.9015)  cardinality_error_1_unscaled: 1857.2500 (1871.0714)  loss_ce_enc_unscaled: 0.4009 (0.4096)  loss_bbox_enc_unscaled: 0.2531 (0.2869)  loss_giou_enc_unscaled: 1.0195 (1.0434)  cardinality_error_enc_unscaled: 1345.5000 (1411.6071)  time: 6.9941  data: 0.0463  max mem: 9227
# Epoch: [0]  [29/30]  eta: 0:00:07  lr: 0.000100  class_error: -0.00  loss: 12.2609 (13.3348)  loss_ce: 0.7436 (0.6461)  loss_bbox: 0.7568 (0.9095)  loss_giou: 1.4416 (1.6411)  loss_ce_0: 0.7114 (0.5916)  loss_bbox_0: 0.8350 (0.9967)  loss_giou_0: 1.5036 (1.7434)  loss_ce_1: 0.7300 (0.6361)  loss_bbox_1: 0.7624 (0.9135)  loss_giou_1: 1.4668 (1.6361)  loss_ce_enc: 0.5601 (0.4804)  loss_bbox_enc: 0.9695 (1.2076)  loss_giou_enc: 1.7110 (1.9327)  loss_ce_unscaled: 0.7436 (0.6461)  class_error_unscaled: 0.0000 (20.4744)  loss_bbox_unscaled: 0.1514 (0.1819)  loss_giou_unscaled: 0.7208 (0.8206)  cardinality_error_unscaled: 1.7500 (676.0750)  loss_ce_0_unscaled: 0.7114 (0.5916)  loss_bbox_0_unscaled: 0.1670 (0.1993)  loss_giou_0_unscaled: 0.7518 (0.8717)  cardinality_error_0_unscaled: 6.2500 (760.3667)  loss_ce_1_unscaled: 0.7300 (0.6361)  loss_bbox_1_unscaled: 0.1525 (0.1827)  loss_giou_1_unscaled: 0.7334 (0.8181)  cardinality_error_1_unscaled: 46.0000 (1312.3083)  loss_ce_enc_unscaled: 0.5601 (0.4804)  loss_bbox_enc_unscaled: 0.1939 (0.2415)  loss_giou_enc_unscaled: 0.8555 (0.9664)  cardinality_error_enc_unscaled: 1229.5000 (1344.9667)  time: 6.9914  data: 0.0487  max mem: 9227
# Epoch: [0] Total time: 0:03:32 (7.0671 s / it)
# Averaged stats: lr: 0.000100  class_error: -0.00  loss: 12.2609 (13.3348)  loss_ce: 0.7436 (0.6461)  loss_bbox: 0.7568 (0.9095)  loss_giou: 1.4416 (1.6411)  loss_ce_0: 0.7114 (0.5916)  loss_bbox_0: 0.8350 (0.9967)  loss_giou_0: 1.5036 (1.7434)  loss_ce_1: 0.7300 (0.6361)  loss_bbox_1: 0.7624 (0.9135)  loss_giou_1: 1.4668 (1.6361)  loss_ce_enc: 0.5601 (0.4804)  loss_bbox_enc: 0.9695 (1.2076)  loss_giou_enc: 1.7110 (1.9327)  loss_ce_unscaled: 0.7436 (0.6461)  class_error_unscaled: 0.0000 (20.4744)  loss_bbox_unscaled: 0.1514 (0.1819)  loss_giou_unscaled: 0.7208 (0.8206)  cardinality_error_unscaled: 1.7500 (676.0750)  loss_ce_0_unscaled: 0.7114 (0.5916)  loss_bbox_0_unscaled: 0.1670 (0.1993)  loss_giou_0_unscaled: 0.7518 (0.8717)  cardinality_error_0_unscaled: 6.2500 (760.3667)  loss_ce_1_unscaled: 0.7300 (0.6361)  loss_bbox_1_unscaled: 0.1525 (0.1827)  loss_giou_1_unscaled: 0.7334 (0.8181)  cardinality_error_1_unscaled: 46.0000 (1312.3083)  loss_ce_enc_unscaled: 0.5601 (0.4804)  loss_bbox_enc_unscaled: 0.1939 (0.2415)  loss_giou_enc_unscaled: 0.8555 (0.9664)  cardinality_error_enc_unscaled: 1229.5000 (1344.9667)
# Test:  [ 0/35]  eta: 0:00:23  class_error: 0.00  loss: 8.4518 (8.4518)  loss_ce: 1.1719 (1.1719)  loss_bbox: 0.2447 (0.2447)  loss_giou: 0.7244 (0.7244)  loss_ce_0: 1.1328 (1.1328)  loss_bbox_0: 0.2250 (0.2250)  loss_giou_0: 0.6767 (0.6767)  loss_ce_1: 1.1172 (1.1172)  loss_bbox_1: 0.2336 (0.2336)  loss_giou_1: 0.6954 (0.6954)  loss_ce_enc: 0.9375 (0.9375)  loss_bbox_enc: 0.2937 (0.2937)  loss_giou_enc: 0.9988 (0.9988)  loss_ce_unscaled: 1.1719 (1.1719)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0489 (0.0489)  loss_giou_unscaled: 0.3622 (0.3622)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 1.1328 (1.1328)  loss_bbox_0_unscaled: 0.0450 (0.0450)  loss_giou_0_unscaled: 0.3384 (0.3384)  cardinality_error_0_unscaled: 1.2500 (1.2500)  loss_ce_1_unscaled: 1.1172 (1.1172)  loss_bbox_1_unscaled: 0.0467 (0.0467)  loss_giou_1_unscaled: 0.3477 (0.3477)  cardinality_error_1_unscaled: 1.2500 (1.2500)  loss_ce_enc_unscaled: 0.9375 (0.9375)  loss_bbox_enc_unscaled: 0.0587 (0.0587)  loss_giou_enc_unscaled: 0.4994 (0.4994)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.6824  data: 0.2801  max mem: 9227
# Test:  [10/35]  eta: 0:00:07  class_error: 0.00  loss: 9.3288 (9.3724)  loss_ce: 1.0078 (1.0050)  loss_bbox: 0.3287 (0.3199)  loss_giou: 1.0129 (1.0129)  loss_ce_0: 0.9727 (0.9506)  loss_bbox_0: 0.3474 (0.3303)  loss_giou_0: 0.9791 (1.0246)  loss_ce_1: 0.9883 (0.9947)  loss_bbox_1: 0.2961 (0.2847)  loss_giou_1: 0.9347 (0.9222)  loss_ce_enc: 0.7930 (0.7685)  loss_bbox_enc: 0.4458 (0.4493)  loss_giou_enc: 1.2970 (1.3098)  loss_ce_unscaled: 1.0078 (1.0050)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0657 (0.0640)  loss_giou_unscaled: 0.5064 (0.5064)  cardinality_error_unscaled: 1.2500 (1.3182)  loss_ce_0_unscaled: 0.9727 (0.9506)  loss_bbox_0_unscaled: 0.0695 (0.0661)  loss_giou_0_unscaled: 0.4896 (0.5123)  cardinality_error_0_unscaled: 1.2500 (1.3182)  loss_ce_1_unscaled: 0.9883 (0.9947)  loss_bbox_1_unscaled: 0.0592 (0.0569)  loss_giou_1_unscaled: 0.4674 (0.4611)  cardinality_error_1_unscaled: 1.2500 (1.3182)  loss_ce_enc_unscaled: 0.7930 (0.7685)  loss_bbox_enc_unscaled: 0.0892 (0.0899)  loss_giou_enc_unscaled: 0.6485 (0.6549)  cardinality_error_enc_unscaled: 1.2500 (1.3182)  time: 0.3092  data: 0.0428  max mem: 9227
# Test:  [20/35]  eta: 0:00:05  class_error: 0.00  loss: 9.4696 (9.6104)  loss_ce: 1.0000 (0.9965)  loss_bbox: 0.3324 (0.3397)  loss_giou: 1.0429 (1.0631)  loss_ce_0: 0.9336 (0.9319)  loss_bbox_0: 0.3586 (0.3628)  loss_giou_0: 1.0167 (1.0841)  loss_ce_1: 0.9570 (0.9680)  loss_bbox_1: 0.3176 (0.3103)  loss_giou_1: 0.9688 (1.0024)  loss_ce_enc: 0.7930 (0.7564)  loss_bbox_enc: 0.4580 (0.4568)  loss_giou_enc: 1.2970 (1.3383)  loss_ce_unscaled: 1.0000 (0.9965)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0665 (0.0679)  loss_giou_unscaled: 0.5214 (0.5316)  cardinality_error_unscaled: 1.2500 (1.2381)  loss_ce_0_unscaled: 0.9336 (0.9319)  loss_bbox_0_unscaled: 0.0717 (0.0726)  loss_giou_0_unscaled: 0.5083 (0.5421)  cardinality_error_0_unscaled: 1.2500 (1.2381)  loss_ce_1_unscaled: 0.9570 (0.9680)  loss_bbox_1_unscaled: 0.0635 (0.0621)  loss_giou_1_unscaled: 0.4844 (0.5012)  cardinality_error_1_unscaled: 1.2500 (1.2262)  loss_ce_enc_unscaled: 0.7930 (0.7564)  loss_bbox_enc_unscaled: 0.0916 (0.0914)  loss_giou_enc_unscaled: 0.6485 (0.6692)  cardinality_error_enc_unscaled: 1.2500 (1.2381)  time: 0.3159  data: 0.0218  max mem: 9227
# Test:  [30/35]  eta: 0:00:01  class_error: 0.00  loss: 9.7278 (9.6415)  loss_ce: 1.0156 (1.0004)  loss_bbox: 0.2949 (0.3409)  loss_giou: 1.0944 (1.0756)  loss_ce_0: 0.9062 (0.9183)  loss_bbox_0: 0.3657 (0.3609)  loss_giou_0: 1.0716 (1.1098)  loss_ce_1: 0.9414 (0.9657)  loss_bbox_1: 0.3250 (0.3037)  loss_giou_1: 1.0136 (1.0171)  loss_ce_enc: 0.7148 (0.7361)  loss_bbox_enc: 0.4230 (0.4449)  loss_giou_enc: 1.3100 (1.3679)  loss_ce_unscaled: 1.0156 (1.0004)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0590 (0.0682)  loss_giou_unscaled: 0.5472 (0.5378)  cardinality_error_unscaled: 1.0000 (1.2177)  loss_ce_0_unscaled: 0.9062 (0.9183)  loss_bbox_0_unscaled: 0.0731 (0.0722)  loss_giou_0_unscaled: 0.5358 (0.5549)  cardinality_error_0_unscaled: 1.0000 (1.2177)  loss_ce_1_unscaled: 0.9414 (0.9657)  loss_bbox_1_unscaled: 0.0650 (0.0607)  loss_giou_1_unscaled: 0.5068 (0.5086)  cardinality_error_1_unscaled: 1.0000 (1.2097)  loss_ce_enc_unscaled: 0.7148 (0.7361)  loss_bbox_enc_unscaled: 0.0846 (0.0890)  loss_giou_enc_unscaled: 0.6550 (0.6840)  cardinality_error_enc_unscaled: 1.0000 (1.2177)  time: 0.3165  data: 0.0219  max mem: 9227
# Test:  [34/35]  eta: 0:00:00  class_error: 0.00  loss: 9.4458 (9.5866)  loss_ce: 1.0156 (1.0036)  loss_bbox: 0.2945 (0.3306)  loss_giou: 1.0056 (1.0640)  loss_ce_0: 0.9062 (0.9129)  loss_bbox_0: 0.3429 (0.3570)  loss_giou_0: 1.0716 (1.1145)  loss_ce_1: 0.9492 (0.9694)  loss_bbox_1: 0.2793 (0.2945)  loss_giou_1: 1.0136 (1.0061)  loss_ce_enc: 0.7812 (0.7377)  loss_bbox_enc: 0.3889 (0.4327)  loss_giou_enc: 1.2546 (1.3637)  loss_ce_unscaled: 1.0156 (1.0036)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0589 (0.0661)  loss_giou_unscaled: 0.5028 (0.5320)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 0.9062 (0.9129)  loss_bbox_0_unscaled: 0.0686 (0.0714)  loss_giou_0_unscaled: 0.5358 (0.5573)  cardinality_error_0_unscaled: 1.2500 (1.2500)  loss_ce_1_unscaled: 0.9492 (0.9694)  loss_bbox_1_unscaled: 0.0559 (0.0589)  loss_giou_1_unscaled: 0.5068 (0.5030)  cardinality_error_1_unscaled: 1.2500 (1.2429)  loss_ce_enc_unscaled: 0.7812 (0.7377)  loss_bbox_enc_unscaled: 0.0778 (0.0865)  loss_giou_enc_unscaled: 0.6273 (0.6819)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.3105  data: 0.0206  max mem: 9227
# Test: Total time: 0:00:10 (0.3097 s / it)
# Averaged stats: class_error: 0.00  loss: 9.4458 (9.5866)  loss_ce: 1.0156 (1.0036)  loss_bbox: 0.2945 (0.3306)  loss_giou: 1.0056 (1.0640)  loss_ce_0: 0.9062 (0.9129)  loss_bbox_0: 0.3429 (0.3570)  loss_giou_0: 1.0716 (1.1145)  loss_ce_1: 0.9492 (0.9694)  loss_bbox_1: 0.2793 (0.2945)  loss_giou_1: 1.0136 (1.0061)  loss_ce_enc: 0.7812 (0.7377)  loss_bbox_enc: 0.3889 (0.4327)  loss_giou_enc: 1.2546 (1.3637)  loss_ce_unscaled: 1.0156 (1.0036)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0589 (0.0661)  loss_giou_unscaled: 0.5028 (0.5320)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 0.9062 (0.9129)  loss_bbox_0_unscaled: 0.0686 (0.0714)  loss_giou_0_unscaled: 0.5358 (0.5573)  cardinality_error_0_unscaled: 1.2500 (1.2500)  loss_ce_1_unscaled: 0.9492 (0.9694)  loss_bbox_1_unscaled: 0.0559 (0.0589)  loss_giou_1_unscaled: 0.5068 (0.5030)  cardinality_error_1_unscaled: 1.2500 (1.2429)  loss_ce_enc_unscaled: 0.7812 (0.7377)  loss_bbox_enc_unscaled: 0.0778 (0.0865)  loss_giou_enc_unscaled: 0.6273 (0.6819)  cardinality_error_enc_unscaled: 1.2500 (1.2500)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.186
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.367
# Test:  [ 0/35]  eta: 0:00:21  class_error: 0.00  loss: 8.7143 (8.7143)  loss_ce: 1.1406 (1.1406)  loss_bbox: 0.2827 (0.2827)  loss_giou: 0.8254 (0.8254)  loss_ce_0: 1.1094 (1.1094)  loss_bbox_0: 0.2504 (0.2504)  loss_giou_0: 0.7303 (0.7303)  loss_ce_1: 1.1406 (1.1406)  loss_bbox_1: 0.2508 (0.2508)  loss_giou_1: 0.6723 (0.6723)  loss_ce_enc: 0.9141 (0.9141)  loss_bbox_enc: 0.3590 (0.3590)  loss_giou_enc: 1.0388 (1.0388)  loss_ce_unscaled: 1.1406 (1.1406)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0565 (0.0565)  loss_giou_unscaled: 0.4127 (0.4127)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 1.1094 (1.1094)  loss_bbox_0_unscaled: 0.0501 (0.0501)  loss_giou_0_unscaled: 0.3652 (0.3652)  cardinality_error_0_unscaled: 1.2500 (1.2500)  loss_ce_1_unscaled: 1.1406 (1.1406)  loss_bbox_1_unscaled: 0.0502 (0.0502)  loss_giou_1_unscaled: 0.3362 (0.3362)  cardinality_error_1_unscaled: 1.2500 (1.2500)  loss_ce_enc_unscaled: 0.9141 (0.9141)  loss_bbox_enc_unscaled: 0.0718 (0.0718)  loss_giou_enc_unscaled: 0.5194 (0.5194)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.6277  data: 0.3435  max mem: 9227
# Test:  [10/35]  eta: 0:00:07  class_error: 0.00  loss: 9.4583 (9.4807)  loss_ce: 1.0000 (0.9883)  loss_bbox: 0.3304 (0.3301)  loss_giou: 1.0741 (1.0473)  loss_ce_0: 0.9375 (0.9311)  loss_bbox_0: 0.3316 (0.3302)  loss_giou_0: 1.0439 (1.0634)  loss_ce_1: 0.9883 (0.9790)  loss_bbox_1: 0.2716 (0.2917)  loss_giou_1: 0.9493 (0.9556)  loss_ce_enc: 0.7578 (0.7358)  loss_bbox_enc: 0.4193 (0.4563)  loss_giou_enc: 1.3259 (1.3718)  loss_ce_unscaled: 1.0000 (0.9883)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0661 (0.0660)  loss_giou_unscaled: 0.5370 (0.5236)  cardinality_error_unscaled: 1.2500 (1.3182)  loss_ce_0_unscaled: 0.9375 (0.9311)  loss_bbox_0_unscaled: 0.0663 (0.0660)  loss_giou_0_unscaled: 0.5220 (0.5317)  cardinality_error_0_unscaled: 1.2500 (1.3182)  loss_ce_1_unscaled: 0.9883 (0.9790)  loss_bbox_1_unscaled: 0.0543 (0.0583)  loss_giou_1_unscaled: 0.4747 (0.4778)  cardinality_error_1_unscaled: 1.2500 (1.3182)  loss_ce_enc_unscaled: 0.7578 (0.7358)  loss_bbox_enc_unscaled: 0.0839 (0.0913)  loss_giou_enc_unscaled: 0.6629 (0.6859)  cardinality_error_enc_unscaled: 1.2500 (1.3182)  time: 0.3135  data: 0.0478  max mem: 9227
# Test:  [20/35]  eta: 0:00:04  class_error: 0.00  loss: 9.5809 (9.6203)  loss_ce: 1.0000 (1.0143)  loss_bbox: 0.3261 (0.3287)  loss_giou: 1.0179 (1.0269)  loss_ce_0: 0.9297 (0.9215)  loss_bbox_0: 0.3316 (0.3544)  loss_giou_0: 1.0576 (1.1025)  loss_ce_1: 0.9805 (0.9673)  loss_bbox_1: 0.3014 (0.3103)  loss_giou_1: 0.9656 (1.0113)  loss_ce_enc: 0.7578 (0.7358)  loss_bbox_enc: 0.4523 (0.4696)  loss_giou_enc: 1.2875 (1.3778)  loss_ce_unscaled: 1.0000 (1.0143)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0652 (0.0657)  loss_giou_unscaled: 0.5089 (0.5134)  cardinality_error_unscaled: 1.2500 (1.2381)  loss_ce_0_unscaled: 0.9297 (0.9215)  loss_bbox_0_unscaled: 0.0663 (0.0709)  loss_giou_0_unscaled: 0.5288 (0.5512)  cardinality_error_0_unscaled: 1.0000 (1.2143)  loss_ce_1_unscaled: 0.9805 (0.9673)  loss_bbox_1_unscaled: 0.0603 (0.0621)  loss_giou_1_unscaled: 0.4828 (0.5057)  cardinality_error_1_unscaled: 1.2500 (1.2262)  loss_ce_enc_unscaled: 0.7578 (0.7358)  loss_bbox_enc_unscaled: 0.0905 (0.0939)  loss_giou_enc_unscaled: 0.6437 (0.6889)  cardinality_error_enc_unscaled: 1.2500 (1.2381)  time: 0.2976  data: 0.0225  max mem: 9227
# Test:  [30/35]  eta: 0:00:01  class_error: 0.00  loss: 9.6639 (9.6594)  loss_ce: 1.0312 (1.0116)  loss_bbox: 0.3246 (0.3336)  loss_giou: 1.0179 (1.0543)  loss_ce_0: 0.8945 (0.9086)  loss_bbox_0: 0.3319 (0.3517)  loss_giou_0: 1.1064 (1.1286)  loss_ce_1: 0.9531 (0.9656)  loss_bbox_1: 0.2722 (0.3039)  loss_giou_1: 1.0046 (1.0247)  loss_ce_enc: 0.7773 (0.7225)  loss_bbox_enc: 0.4246 (0.4556)  loss_giou_enc: 1.2573 (1.3987)  loss_ce_unscaled: 1.0312 (1.0116)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0649 (0.0667)  loss_giou_unscaled: 0.5089 (0.5272)  cardinality_error_unscaled: 1.0000 (1.2177)  loss_ce_0_unscaled: 0.8945 (0.9086)  loss_bbox_0_unscaled: 0.0664 (0.0703)  loss_giou_0_unscaled: 0.5532 (0.5643)  cardinality_error_0_unscaled: 1.0000 (1.2016)  loss_ce_1_unscaled: 0.9531 (0.9656)  loss_bbox_1_unscaled: 0.0544 (0.0608)  loss_giou_1_unscaled: 0.5023 (0.5124)  cardinality_error_1_unscaled: 1.0000 (1.2097)  loss_ce_enc_unscaled: 0.7773 (0.7225)  loss_bbox_enc_unscaled: 0.0849 (0.0911)  loss_giou_enc_unscaled: 0.6287 (0.6993)  cardinality_error_enc_unscaled: 1.0000 (1.2177)  time: 0.3256  data: 0.0232  max mem: 9227
# Test:  [34/35]  eta: 0:00:00  class_error: 0.00  loss: 9.3481 (9.6134)  loss_ce: 1.0312 (1.0110)  loss_bbox: 0.3223 (0.3239)  loss_giou: 1.0277 (1.0493)  loss_ce_0: 0.8945 (0.9051)  loss_bbox_0: 0.3104 (0.3501)  loss_giou_0: 1.1064 (1.1309)  loss_ce_1: 0.9531 (0.9631)  loss_bbox_1: 0.2488 (0.2955)  loss_giou_1: 1.0046 (1.0238)  loss_ce_enc: 0.7773 (0.7244)  loss_bbox_enc: 0.3964 (0.4412)  loss_giou_enc: 1.2573 (1.3951)  loss_ce_unscaled: 1.0312 (1.0110)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0645 (0.0648)  loss_giou_unscaled: 0.5138 (0.5246)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 0.8945 (0.9051)  loss_bbox_0_unscaled: 0.0621 (0.0700)  loss_giou_0_unscaled: 0.5532 (0.5654)  cardinality_error_0_unscaled: 1.0000 (1.2286)  loss_ce_1_unscaled: 0.9531 (0.9631)  loss_bbox_1_unscaled: 0.0498 (0.0591)  loss_giou_1_unscaled: 0.5023 (0.5119)  cardinality_error_1_unscaled: 1.2500 (1.2429)  loss_ce_enc_unscaled: 0.7773 (0.7244)  loss_bbox_enc_unscaled: 0.0793 (0.0882)  loss_giou_enc_unscaled: 0.6287 (0.6976)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.3219  data: 0.0225  max mem: 9227
# Test: Total time: 0:00:11 (0.3175 s / it)
# Averaged stats: class_error: 0.00  loss: 9.3481 (9.6134)  loss_ce: 1.0312 (1.0110)  loss_bbox: 0.3223 (0.3239)  loss_giou: 1.0277 (1.0493)  loss_ce_0: 0.8945 (0.9051)  loss_bbox_0: 0.3104 (0.3501)  loss_giou_0: 1.1064 (1.1309)  loss_ce_1: 0.9531 (0.9631)  loss_bbox_1: 0.2488 (0.2955)  loss_giou_1: 1.0046 (1.0238)  loss_ce_enc: 0.7773 (0.7244)  loss_bbox_enc: 0.3964 (0.4412)  loss_giou_enc: 1.2573 (1.3951)  loss_ce_unscaled: 1.0312 (1.0110)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0645 (0.0648)  loss_giou_unscaled: 0.5138 (0.5246)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 0.8945 (0.9051)  loss_bbox_0_unscaled: 0.0621 (0.0700)  loss_giou_0_unscaled: 0.5532 (0.5654)  cardinality_error_0_unscaled: 1.0000 (1.2286)  loss_ce_1_unscaled: 0.9531 (0.9631)  loss_bbox_1_unscaled: 0.0498 (0.0591)  loss_giou_1_unscaled: 0.5023 (0.5119)  cardinality_error_1_unscaled: 1.2500 (1.2429)  loss_ce_enc_unscaled: 0.7773 (0.7244)  loss_bbox_enc_unscaled: 0.0793 (0.0882)  loss_giou_enc_unscaled: 0.6287 (0.6976)  cardinality_error_enc_unscaled: 1.2500 (1.2500)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.275
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 30
# Epoch: [1]  [ 0/30]  eta: 0:04:18  lr: 0.000100  class_error: 0.00  loss: 10.4786 (10.4786)  loss_ce: 0.9945 (0.9945)  loss_bbox: 0.4969 (0.4969)  loss_giou: 1.0087 (1.0087)  loss_ce_0: 0.8978 (0.8978)  loss_bbox_0: 0.5908 (0.5908)  loss_giou_0: 1.1469 (1.1469)  loss_ce_1: 0.9184 (0.9184)  loss_bbox_1: 0.5543 (0.5543)  loss_giou_1: 1.1005 (1.1005)  loss_ce_enc: 0.7514 (0.7514)  loss_bbox_enc: 0.7030 (0.7030)  loss_giou_enc: 1.3156 (1.3156)  loss_ce_unscaled: 0.9945 (0.9945)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0994 (0.0994)  loss_giou_unscaled: 0.5043 (0.5043)  cardinality_error_unscaled: 1.5000 (1.5000)  loss_ce_0_unscaled: 0.8978 (0.8978)  loss_bbox_0_unscaled: 0.1182 (0.1182)  loss_giou_0_unscaled: 0.5734 (0.5734)  cardinality_error_0_unscaled: 2.0000 (2.0000)  loss_ce_1_unscaled: 0.9184 (0.9184)  loss_bbox_1_unscaled: 0.1109 (0.1109)  loss_giou_1_unscaled: 0.5502 (0.5502)  cardinality_error_1_unscaled: 1.5000 (1.5000)  loss_ce_enc_unscaled: 0.7514 (0.7514)  loss_bbox_enc_unscaled: 0.1406 (0.1406)  loss_giou_enc_unscaled: 0.6578 (0.6578)  cardinality_error_enc_unscaled: 1126.5000 (1126.5000)  time: 8.6115  data: 1.2371  max mem: 9227
# Epoch: [1]  [10/30]  eta: 0:02:23  lr: 0.000100  class_error: -0.00  loss: 9.5767 (9.7427)  loss_ce: 0.9351 (0.9127)  loss_bbox: 0.3350 (0.3421)  loss_giou: 1.0675 (1.1165)  loss_ce_0: 0.9036 (0.8941)  loss_bbox_0: 0.3664 (0.3595)  loss_giou_0: 1.1295 (1.1636)  loss_ce_1: 0.9319 (0.9217)  loss_bbox_1: 0.3357 (0.3451)  loss_giou_1: 1.1005 (1.1013)  loss_ce_enc: 0.7207 (0.7104)  loss_bbox_enc: 0.4414 (0.4680)  loss_giou_enc: 1.3907 (1.4076)  loss_ce_unscaled: 0.9351 (0.9127)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0670 (0.0684)  loss_giou_unscaled: 0.5337 (0.5582)  cardinality_error_unscaled: 1.2500 (1.2955)  loss_ce_0_unscaled: 0.9036 (0.8941)  loss_bbox_0_unscaled: 0.0733 (0.0719)  loss_giou_0_unscaled: 0.5648 (0.5818)  cardinality_error_0_unscaled: 1.0000 (1.1818)  loss_ce_1_unscaled: 0.9319 (0.9217)  loss_bbox_1_unscaled: 0.0671 (0.0690)  loss_giou_1_unscaled: 0.5502 (0.5507)  cardinality_error_1_unscaled: 1.2500 (1.2500)  loss_ce_enc_unscaled: 0.7207 (0.7104)  loss_bbox_enc_unscaled: 0.0883 (0.0936)  loss_giou_enc_unscaled: 0.6953 (0.7038)  cardinality_error_enc_unscaled: 864.2500 (860.8864)  time: 7.1894  data: 0.1567  max mem: 9227
# Epoch: [1]  [20/30]  eta: 0:01:11  lr: 0.000100  class_error: 0.00  loss: 9.4968 (9.6386)  loss_ce: 0.9049 (0.9045)  loss_bbox: 0.3166 (0.3360)  loss_giou: 1.0675 (1.0904)  loss_ce_0: 0.8889 (0.8838)  loss_bbox_0: 0.3350 (0.3594)  loss_giou_0: 1.1295 (1.1502)  loss_ce_1: 0.9319 (0.9190)  loss_bbox_1: 0.3202 (0.3416)  loss_giou_1: 1.0906 (1.0860)  loss_ce_enc: 0.7199 (0.7134)  loss_bbox_enc: 0.4414 (0.4652)  loss_giou_enc: 1.3764 (1.3892)  loss_ce_unscaled: 0.9049 (0.9045)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0633 (0.0672)  loss_giou_unscaled: 0.5337 (0.5452)  cardinality_error_unscaled: 1.2500 (1.5238)  loss_ce_0_unscaled: 0.8889 (0.8838)  loss_bbox_0_unscaled: 0.0670 (0.0719)  loss_giou_0_unscaled: 0.5648 (0.5751)  cardinality_error_0_unscaled: 2.0000 (11.0714)  loss_ce_1_unscaled: 0.9319 (0.9190)  loss_bbox_1_unscaled: 0.0640 (0.0683)  loss_giou_1_unscaled: 0.5453 (0.5430)  cardinality_error_1_unscaled: 1.2500 (22.0833)  loss_ce_enc_unscaled: 0.7199 (0.7134)  loss_bbox_enc_unscaled: 0.0883 (0.0930)  loss_giou_enc_unscaled: 0.6882 (0.6946)  cardinality_error_enc_unscaled: 634.2500 (712.1786)  time: 7.0446  data: 0.0494  max mem: 9227
# Epoch: [1]  [29/30]  eta: 0:00:07  lr: 0.000100  class_error: -0.00  loss: 9.1794 (9.3963)  loss_ce: 0.9528 (0.9380)  loss_bbox: 0.2990 (0.3136)  loss_giou: 0.9229 (1.0073)  loss_ce_0: 0.8980 (0.9140)  loss_bbox_0: 0.3242 (0.3378)  loss_giou_0: 1.0338 (1.0775)  loss_ce_1: 0.9590 (0.9498)  loss_bbox_1: 0.3042 (0.3170)  loss_giou_1: 0.9156 (1.0111)  loss_ce_enc: 0.7668 (0.7469)  loss_bbox_enc: 0.4133 (0.4491)  loss_giou_enc: 1.2796 (1.3342)  loss_ce_unscaled: 0.9528 (0.9380)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0598 (0.0627)  loss_giou_unscaled: 0.4615 (0.5036)  cardinality_error_unscaled: 1.7500 (2.1833)  loss_ce_0_unscaled: 0.8980 (0.9140)  loss_bbox_0_unscaled: 0.0648 (0.0676)  loss_giou_0_unscaled: 0.5169 (0.5388)  cardinality_error_0_unscaled: 31.0000 (19.5333)  loss_ce_1_unscaled: 0.9590 (0.9498)  loss_bbox_1_unscaled: 0.0608 (0.0634)  loss_giou_1_unscaled: 0.4578 (0.5055)  cardinality_error_1_unscaled: 64.5000 (58.0083)  loss_ce_enc_unscaled: 0.7668 (0.7469)  loss_bbox_enc_unscaled: 0.0827 (0.0898)  loss_giou_enc_unscaled: 0.6398 (0.6671)  cardinality_error_enc_unscaled: 478.5000 (589.7250)  time: 7.0708  data: 0.0494  max mem: 9227
# Epoch: [1] Total time: 0:03:33 (7.1138 s / it)
# Averaged stats: lr: 0.000100  class_error: -0.00  loss: 9.1794 (9.3963)  loss_ce: 0.9528 (0.9380)  loss_bbox: 0.2990 (0.3136)  loss_giou: 0.9229 (1.0073)  loss_ce_0: 0.8980 (0.9140)  loss_bbox_0: 0.3242 (0.3378)  loss_giou_0: 1.0338 (1.0775)  loss_ce_1: 0.9590 (0.9498)  loss_bbox_1: 0.3042 (0.3170)  loss_giou_1: 0.9156 (1.0111)  loss_ce_enc: 0.7668 (0.7469)  loss_bbox_enc: 0.4133 (0.4491)  loss_giou_enc: 1.2796 (1.3342)  loss_ce_unscaled: 0.9528 (0.9380)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0598 (0.0627)  loss_giou_unscaled: 0.4615 (0.5036)  cardinality_error_unscaled: 1.7500 (2.1833)  loss_ce_0_unscaled: 0.8980 (0.9140)  loss_bbox_0_unscaled: 0.0648 (0.0676)  loss_giou_0_unscaled: 0.5169 (0.5388)  cardinality_error_0_unscaled: 31.0000 (19.5333)  loss_ce_1_unscaled: 0.9590 (0.9498)  loss_bbox_1_unscaled: 0.0608 (0.0634)  loss_giou_1_unscaled: 0.4578 (0.5055)  cardinality_error_1_unscaled: 64.5000 (58.0083)  loss_ce_enc_unscaled: 0.7668 (0.7469)  loss_bbox_enc_unscaled: 0.0827 (0.0898)  loss_giou_enc_unscaled: 0.6398 (0.6671)  cardinality_error_enc_unscaled: 478.5000 (589.7250)
# Test:  [ 0/35]  eta: 0:00:22  class_error: 0.00  loss: 7.8799 (7.8799)  loss_ce: 1.1172 (1.1172)  loss_bbox: 0.1493 (0.1493)  loss_giou: 0.5637 (0.5637)  loss_ce_0: 1.1641 (1.1641)  loss_bbox_0: 0.1678 (0.1678)  loss_giou_0: 0.5479 (0.5479)  loss_ce_1: 1.1406 (1.1406)  loss_bbox_1: 0.1580 (0.1580)  loss_giou_1: 0.5358 (0.5358)  loss_ce_enc: 0.9297 (0.9297)  loss_bbox_enc: 0.3294 (0.3294)  loss_giou_enc: 1.0764 (1.0764)  loss_ce_unscaled: 1.1172 (1.1172)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0299 (0.0299)  loss_giou_unscaled: 0.2819 (0.2819)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 1.1641 (1.1641)  loss_bbox_0_unscaled: 0.0336 (0.0336)  loss_giou_0_unscaled: 0.2740 (0.2740)  cardinality_error_0_unscaled: 0.5000 (0.5000)  loss_ce_1_unscaled: 1.1406 (1.1406)  loss_bbox_1_unscaled: 0.0316 (0.0316)  loss_giou_1_unscaled: 0.2679 (0.2679)  cardinality_error_1_unscaled: 3.0000 (3.0000)  loss_ce_enc_unscaled: 0.9297 (0.9297)  loss_bbox_enc_unscaled: 0.0659 (0.0659)  loss_giou_enc_unscaled: 0.5382 (0.5382)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.6553  data: 0.3064  max mem: 9227
# Test:  [10/35]  eta: 0:00:08  class_error: 0.00  loss: 9.5484 (9.3049)  loss_ce: 0.8867 (0.9187)  loss_bbox: 0.3312 (0.3206)  loss_giou: 1.0680 (0.9800)  loss_ce_0: 0.9297 (0.9187)  loss_bbox_0: 0.3247 (0.3112)  loss_giou_0: 0.9883 (1.0116)  loss_ce_1: 0.9336 (0.9442)  loss_bbox_1: 0.3317 (0.3070)  loss_giou_1: 0.9611 (0.9386)  loss_ce_enc: 0.6992 (0.7056)  loss_bbox_enc: 0.5238 (0.5350)  loss_giou_enc: 1.4601 (1.4136)  loss_ce_unscaled: 0.8867 (0.9187)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0662 (0.0641)  loss_giou_unscaled: 0.5340 (0.4900)  cardinality_error_unscaled: 1.2500 (1.2955)  loss_ce_0_unscaled: 0.9297 (0.9187)  loss_bbox_0_unscaled: 0.0649 (0.0622)  loss_giou_0_unscaled: 0.4941 (0.5058)  cardinality_error_0_unscaled: 2.0000 (2.1591)  loss_ce_1_unscaled: 0.9336 (0.9442)  loss_bbox_1_unscaled: 0.0663 (0.0614)  loss_giou_1_unscaled: 0.4805 (0.4693)  cardinality_error_1_unscaled: 3.0000 (5.0227)  loss_ce_enc_unscaled: 0.6992 (0.7056)  loss_bbox_enc_unscaled: 0.1048 (0.1070)  loss_giou_enc_unscaled: 0.7300 (0.7068)  cardinality_error_enc_unscaled: 1.2500 (1.3182)  time: 0.3275  data: 0.0470  max mem: 9227
# Test:  [20/35]  eta: 0:00:04  class_error: 0.00  loss: 9.4237 (9.3984)  loss_ce: 0.9062 (0.9235)  loss_bbox: 0.3312 (0.3213)  loss_giou: 0.9715 (0.9834)  loss_ce_0: 0.9141 (0.8927)  loss_bbox_0: 0.3544 (0.3442)  loss_giou_0: 1.0123 (1.0591)  loss_ce_1: 0.9336 (0.9414)  loss_bbox_1: 0.3367 (0.3203)  loss_giou_1: 0.9139 (0.9694)  loss_ce_enc: 0.6992 (0.7340)  loss_bbox_enc: 0.5177 (0.5255)  loss_giou_enc: 1.4389 (1.3834)  loss_ce_unscaled: 0.9062 (0.9235)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0662 (0.0643)  loss_giou_unscaled: 0.4857 (0.4917)  cardinality_error_unscaled: 1.0000 (1.2143)  loss_ce_0_unscaled: 0.9141 (0.8927)  loss_bbox_0_unscaled: 0.0709 (0.0688)  loss_giou_0_unscaled: 0.5062 (0.5295)  cardinality_error_0_unscaled: 2.0000 (2.2619)  loss_ce_1_unscaled: 0.9336 (0.9414)  loss_bbox_1_unscaled: 0.0673 (0.0641)  loss_giou_1_unscaled: 0.4569 (0.4847)  cardinality_error_1_unscaled: 4.0000 (6.4762)  loss_ce_enc_unscaled: 0.6992 (0.7340)  loss_bbox_enc_unscaled: 0.1035 (0.1051)  loss_giou_enc_unscaled: 0.7195 (0.6917)  cardinality_error_enc_unscaled: 1.2500 (1.2381)  time: 0.2911  data: 0.0220  max mem: 9227
# Test:  [30/35]  eta: 0:00:01  class_error: 0.00  loss: 9.4237 (9.4709)  loss_ce: 0.9062 (0.9069)  loss_bbox: 0.3371 (0.3293)  loss_giou: 0.9486 (1.0128)  loss_ce_0: 0.8867 (0.8725)  loss_bbox_0: 0.3667 (0.3525)  loss_giou_0: 1.0406 (1.0971)  loss_ce_1: 0.9375 (0.9253)  loss_bbox_1: 0.3367 (0.3275)  loss_giou_1: 0.8994 (1.0056)  loss_ce_enc: 0.7539 (0.7278)  loss_bbox_enc: 0.4463 (0.5148)  loss_giou_enc: 1.3270 (1.3989)  loss_ce_unscaled: 0.9062 (0.9069)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0674 (0.0659)  loss_giou_unscaled: 0.4743 (0.5064)  cardinality_error_unscaled: 1.0000 (1.1855)  loss_ce_0_unscaled: 0.8867 (0.8725)  loss_bbox_0_unscaled: 0.0733 (0.0705)  loss_giou_0_unscaled: 0.5203 (0.5486)  cardinality_error_0_unscaled: 2.0000 (2.2661)  loss_ce_1_unscaled: 0.9375 (0.9253)  loss_bbox_1_unscaled: 0.0673 (0.0655)  loss_giou_1_unscaled: 0.4497 (0.5028)  cardinality_error_1_unscaled: 6.5000 (6.3226)  loss_ce_enc_unscaled: 0.7539 (0.7278)  loss_bbox_enc_unscaled: 0.0893 (0.1030)  loss_giou_enc_unscaled: 0.6635 (0.6995)  cardinality_error_enc_unscaled: 1.0000 (1.2177)  time: 0.2814  data: 0.0213  max mem: 9227
# Test:  [34/35]  eta: 0:00:00  class_error: 0.00  loss: 9.2531 (9.4962)  loss_ce: 0.8828 (0.8954)  loss_bbox: 0.3371 (0.3339)  loss_giou: 1.0130 (1.0350)  loss_ce_0: 0.8867 (0.8654)  loss_bbox_0: 0.3113 (0.3507)  loss_giou_0: 1.0563 (1.1074)  loss_ce_1: 0.9062 (0.9183)  loss_bbox_1: 0.3141 (0.3276)  loss_giou_1: 0.9542 (1.0222)  loss_ce_enc: 0.7148 (0.7197)  loss_bbox_enc: 0.4226 (0.5102)  loss_giou_enc: 1.3791 (1.4104)  loss_ce_unscaled: 0.8828 (0.8954)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0674 (0.0668)  loss_giou_unscaled: 0.5065 (0.5175)  cardinality_error_unscaled: 1.0000 (1.2214)  loss_ce_0_unscaled: 0.8867 (0.8654)  loss_bbox_0_unscaled: 0.0623 (0.0701)  loss_giou_0_unscaled: 0.5281 (0.5537)  cardinality_error_0_unscaled: 2.0000 (2.2571)  loss_ce_1_unscaled: 0.9062 (0.9183)  loss_bbox_1_unscaled: 0.0628 (0.0655)  loss_giou_1_unscaled: 0.4771 (0.5111)  cardinality_error_1_unscaled: 8.0000 (7.0190)  loss_ce_enc_unscaled: 0.7148 (0.7197)  loss_bbox_enc_unscaled: 0.0845 (0.1020)  loss_giou_enc_unscaled: 0.6895 (0.7052)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.2707  data: 0.0187  max mem: 9227
# Test: Total time: 0:00:10 (0.2953 s / it)
# Averaged stats: class_error: 0.00  loss: 9.2531 (9.4962)  loss_ce: 0.8828 (0.8954)  loss_bbox: 0.3371 (0.3339)  loss_giou: 1.0130 (1.0350)  loss_ce_0: 0.8867 (0.8654)  loss_bbox_0: 0.3113 (0.3507)  loss_giou_0: 1.0563 (1.1074)  loss_ce_1: 0.9062 (0.9183)  loss_bbox_1: 0.3141 (0.3276)  loss_giou_1: 0.9542 (1.0222)  loss_ce_enc: 0.7148 (0.7197)  loss_bbox_enc: 0.4226 (0.5102)  loss_giou_enc: 1.3791 (1.4104)  loss_ce_unscaled: 0.8828 (0.8954)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0674 (0.0668)  loss_giou_unscaled: 0.5065 (0.5175)  cardinality_error_unscaled: 1.0000 (1.2214)  loss_ce_0_unscaled: 0.8867 (0.8654)  loss_bbox_0_unscaled: 0.0623 (0.0701)  loss_giou_0_unscaled: 0.5281 (0.5537)  cardinality_error_0_unscaled: 2.0000 (2.2571)  loss_ce_1_unscaled: 0.9062 (0.9183)  loss_bbox_1_unscaled: 0.0628 (0.0655)  loss_giou_1_unscaled: 0.4771 (0.5111)  cardinality_error_1_unscaled: 8.0000 (7.0190)  loss_ce_enc_unscaled: 0.7148 (0.7197)  loss_bbox_enc_unscaled: 0.0845 (0.1020)  loss_giou_enc_unscaled: 0.6895 (0.7052)  cardinality_error_enc_unscaled: 1.2500 (1.2500)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.383
# Test:  [ 0/35]  eta: 0:00:21  class_error: 0.00  loss: 7.8228 (7.8228)  loss_ce: 1.1250 (1.1250)  loss_bbox: 0.1504 (0.1504)  loss_giou: 0.5617 (0.5617)  loss_ce_0: 1.1641 (1.1641)  loss_bbox_0: 0.1458 (0.1458)  loss_giou_0: 0.5552 (0.5552)  loss_ce_1: 1.1406 (1.1406)  loss_bbox_1: 0.1564 (0.1564)  loss_giou_1: 0.5474 (0.5474)  loss_ce_enc: 0.9609 (0.9609)  loss_bbox_enc: 0.3133 (0.3133)  loss_giou_enc: 1.0020 (1.0020)  loss_ce_unscaled: 1.1250 (1.1250)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0301 (0.0301)  loss_giou_unscaled: 0.2809 (0.2809)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 1.1641 (1.1641)  loss_bbox_0_unscaled: 0.0292 (0.0292)  loss_giou_0_unscaled: 0.2776 (0.2776)  cardinality_error_0_unscaled: 0.7500 (0.7500)  loss_ce_1_unscaled: 1.1406 (1.1406)  loss_bbox_1_unscaled: 0.0313 (0.0313)  loss_giou_1_unscaled: 0.2737 (0.2737)  cardinality_error_1_unscaled: 2.5000 (2.5000)  loss_ce_enc_unscaled: 0.9609 (0.9609)  loss_bbox_enc_unscaled: 0.0627 (0.0627)  loss_giou_enc_unscaled: 0.5010 (0.5010)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.6093  data: 0.2944  max mem: 9227
# Test:  [10/35]  eta: 0:00:09  class_error: 0.00  loss: 9.5555 (9.3924)  loss_ce: 0.8945 (0.9421)  loss_bbox: 0.3184 (0.3142)  loss_giou: 0.9591 (0.9399)  loss_ce_0: 0.8789 (0.8999)  loss_bbox_0: 0.3820 (0.3753)  loss_giou_0: 1.0240 (1.0207)  loss_ce_1: 0.9258 (0.9258)  loss_bbox_1: 0.3356 (0.3241)  loss_giou_1: 1.0159 (0.9884)  loss_ce_enc: 0.6758 (0.7219)  loss_bbox_enc: 0.5866 (0.5599)  loss_giou_enc: 1.3955 (1.3802)  loss_ce_unscaled: 0.8945 (0.9421)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0637 (0.0628)  loss_giou_unscaled: 0.4795 (0.4699)  cardinality_error_unscaled: 1.2500 (1.2273)  loss_ce_0_unscaled: 0.8789 (0.8999)  loss_bbox_0_unscaled: 0.0764 (0.0751)  loss_giou_0_unscaled: 0.5120 (0.5103)  cardinality_error_0_unscaled: 2.2500 (2.2273)  loss_ce_1_unscaled: 0.9258 (0.9258)  loss_bbox_1_unscaled: 0.0671 (0.0648)  loss_giou_1_unscaled: 0.5079 (0.4942)  cardinality_error_1_unscaled: 3.5000 (4.9773)  loss_ce_enc_unscaled: 0.6758 (0.7219)  loss_bbox_enc_unscaled: 0.1173 (0.1120)  loss_giou_enc_unscaled: 0.6977 (0.6901)  cardinality_error_enc_unscaled: 1.2500 (1.3182)  time: 0.3739  data: 0.0453  max mem: 9227
# Test:  [20/35]  eta: 0:00:05  class_error: 0.00  loss: 9.3134 (9.4765)  loss_ce: 0.8945 (0.9241)  loss_bbox: 0.3260 (0.3325)  loss_giou: 0.9663 (0.9843)  loss_ce_0: 0.8750 (0.8843)  loss_bbox_0: 0.3820 (0.3785)  loss_giou_0: 1.0581 (1.0683)  loss_ce_1: 0.9258 (0.9308)  loss_bbox_1: 0.3259 (0.3192)  loss_giou_1: 0.9954 (0.9955)  loss_ce_enc: 0.6719 (0.7282)  loss_bbox_enc: 0.5343 (0.5397)  loss_giou_enc: 1.4675 (1.3911)  loss_ce_unscaled: 0.8945 (0.9241)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0652 (0.0665)  loss_giou_unscaled: 0.4831 (0.4922)  cardinality_error_unscaled: 1.0000 (1.1429)  loss_ce_0_unscaled: 0.8750 (0.8843)  loss_bbox_0_unscaled: 0.0764 (0.0757)  loss_giou_0_unscaled: 0.5291 (0.5341)  cardinality_error_0_unscaled: 2.2500 (2.4167)  loss_ce_1_unscaled: 0.9258 (0.9308)  loss_bbox_1_unscaled: 0.0652 (0.0638)  loss_giou_1_unscaled: 0.4977 (0.4977)  cardinality_error_1_unscaled: 3.7500 (6.3333)  loss_ce_enc_unscaled: 0.6719 (0.7282)  loss_bbox_enc_unscaled: 0.1069 (0.1079)  loss_giou_enc_unscaled: 0.7338 (0.6956)  cardinality_error_enc_unscaled: 1.2500 (1.2381)  time: 0.3275  data: 0.0223  max mem: 9227
# Test:  [30/35]  eta: 0:00:01  class_error: 0.00  loss: 9.1946 (9.5029)  loss_ce: 0.8945 (0.9103)  loss_bbox: 0.3346 (0.3322)  loss_giou: 0.9624 (1.0156)  loss_ce_0: 0.8750 (0.8721)  loss_bbox_0: 0.3434 (0.3747)  loss_giou_0: 1.0446 (1.0925)  loss_ce_1: 0.9453 (0.9207)  loss_bbox_1: 0.2858 (0.3179)  loss_giou_1: 0.9258 (1.0209)  loss_ce_enc: 0.7266 (0.7295)  loss_bbox_enc: 0.4213 (0.5231)  loss_giou_enc: 1.3512 (1.3934)  loss_ce_unscaled: 0.8945 (0.9103)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0669 (0.0664)  loss_giou_unscaled: 0.4812 (0.5078)  cardinality_error_unscaled: 1.0000 (1.1371)  loss_ce_0_unscaled: 0.8750 (0.8721)  loss_bbox_0_unscaled: 0.0687 (0.0749)  loss_giou_0_unscaled: 0.5223 (0.5462)  cardinality_error_0_unscaled: 2.2500 (2.3387)  loss_ce_1_unscaled: 0.9453 (0.9207)  loss_bbox_1_unscaled: 0.0572 (0.0636)  loss_giou_1_unscaled: 0.4629 (0.5105)  cardinality_error_1_unscaled: 5.7500 (6.0000)  loss_ce_enc_unscaled: 0.7266 (0.7295)  loss_bbox_enc_unscaled: 0.0843 (0.1046)  loss_giou_enc_unscaled: 0.6756 (0.6967)  cardinality_error_enc_unscaled: 1.0000 (1.2177)  time: 0.2954  data: 0.0216  max mem: 9227
# Test:  [34/35]  eta: 0:00:00  class_error: 0.00  loss: 9.0528 (9.5215)  loss_ce: 0.8945 (0.9045)  loss_bbox: 0.3154 (0.3317)  loss_giou: 0.9707 (1.0281)  loss_ce_0: 0.8750 (0.8652)  loss_bbox_0: 0.3066 (0.3734)  loss_giou_0: 1.0446 (1.1023)  loss_ce_1: 0.9180 (0.9114)  loss_bbox_1: 0.2783 (0.3239)  loss_giou_1: 0.9615 (1.0364)  loss_ce_enc: 0.7031 (0.7229)  loss_bbox_enc: 0.4021 (0.5180)  loss_giou_enc: 1.3512 (1.4038)  loss_ce_unscaled: 0.8945 (0.9045)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0631 (0.0663)  loss_giou_unscaled: 0.4853 (0.5140)  cardinality_error_unscaled: 1.0000 (1.1714)  loss_ce_0_unscaled: 0.8750 (0.8652)  loss_bbox_0_unscaled: 0.0613 (0.0747)  loss_giou_0_unscaled: 0.5223 (0.5512)  cardinality_error_0_unscaled: 2.2500 (2.2476)  loss_ce_1_unscaled: 0.9180 (0.9114)  loss_bbox_1_unscaled: 0.0557 (0.0648)  loss_giou_1_unscaled: 0.4808 (0.5182)  cardinality_error_1_unscaled: 7.5000 (6.6333)  loss_ce_enc_unscaled: 0.7031 (0.7229)  loss_bbox_enc_unscaled: 0.0804 (0.1036)  loss_giou_enc_unscaled: 0.6756 (0.7019)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.2834  data: 0.0194  max mem: 9227
# Test: Total time: 0:00:11 (0.3195 s / it)
# Averaged stats: class_error: 0.00  loss: 9.0528 (9.5215)  loss_ce: 0.8945 (0.9045)  loss_bbox: 0.3154 (0.3317)  loss_giou: 0.9707 (1.0281)  loss_ce_0: 0.8750 (0.8652)  loss_bbox_0: 0.3066 (0.3734)  loss_giou_0: 1.0446 (1.1023)  loss_ce_1: 0.9180 (0.9114)  loss_bbox_1: 0.2783 (0.3239)  loss_giou_1: 0.9615 (1.0364)  loss_ce_enc: 0.7031 (0.7229)  loss_bbox_enc: 0.4021 (0.5180)  loss_giou_enc: 1.3512 (1.4038)  loss_ce_unscaled: 0.8945 (0.9045)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0631 (0.0663)  loss_giou_unscaled: 0.4853 (0.5140)  cardinality_error_unscaled: 1.0000 (1.1714)  loss_ce_0_unscaled: 0.8750 (0.8652)  loss_bbox_0_unscaled: 0.0613 (0.0747)  loss_giou_0_unscaled: 0.5223 (0.5512)  cardinality_error_0_unscaled: 2.2500 (2.2476)  loss_ce_1_unscaled: 0.9180 (0.9114)  loss_bbox_1_unscaled: 0.0557 (0.0648)  loss_giou_1_unscaled: 0.4808 (0.5182)  cardinality_error_1_unscaled: 7.5000 (6.6333)  loss_ce_enc_unscaled: 0.7031 (0.7229)  loss_bbox_enc_unscaled: 0.0804 (0.1036)  loss_giou_enc_unscaled: 0.6756 (0.7019)  cardinality_error_enc_unscaled: 1.2500 (1.2500)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.458
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 30
# ...
# Test:  [ 0/35]  eta: 0:00:23  class_error: 0.00  loss: 6.4172 (6.4172)  loss_ce: 0.7969 (0.7969)  loss_bbox: 0.1547 (0.1547)  loss_giou: 0.6404 (0.6404)  loss_ce_0: 0.9883 (0.9883)  loss_bbox_0: 0.1665 (0.1665)  loss_giou_0: 0.5266 (0.5266)  loss_ce_1: 0.7578 (0.7578)  loss_bbox_1: 0.1845 (0.1845)  loss_giou_1: 0.6910 (0.6910)  loss_ce_enc: 0.8242 (0.8242)  loss_bbox_enc: 0.1406 (0.1406)  loss_giou_enc: 0.5456 (0.5456)  loss_ce_unscaled: 0.7969 (0.7969)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0309 (0.0309)  loss_giou_unscaled: 0.3202 (0.3202)  cardinality_error_unscaled: 3.5000 (3.5000)  loss_ce_0_unscaled: 0.9883 (0.9883)  loss_bbox_0_unscaled: 0.0333 (0.0333)  loss_giou_0_unscaled: 0.2633 (0.2633)  cardinality_error_0_unscaled: 2.2500 (2.2500)  loss_ce_1_unscaled: 0.7578 (0.7578)  loss_bbox_1_unscaled: 0.0369 (0.0369)  loss_giou_1_unscaled: 0.3455 (0.3455)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 0.8242 (0.8242)  loss_bbox_enc_unscaled: 0.0281 (0.0281)  loss_giou_enc_unscaled: 0.2728 (0.2728)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.6590  data: 0.2800  max mem: 9336
# Test:  [10/35]  eta: 0:00:08  class_error: 0.00  loss: 7.5505 (7.0773)  loss_ce: 0.7969 (0.7926)  loss_bbox: 0.2449 (0.2146)  loss_giou: 0.7719 (0.7696)  loss_ce_0: 0.9727 (0.9492)  loss_bbox_0: 0.1586 (0.1797)  loss_giou_0: 0.6892 (0.6598)  loss_ce_1: 0.7930 (0.7944)  loss_bbox_1: 0.2265 (0.2254)  loss_giou_1: 0.7537 (0.7679)  loss_ce_enc: 0.8164 (0.8423)  loss_bbox_enc: 0.1915 (0.1943)  loss_giou_enc: 0.6216 (0.6876)  loss_ce_unscaled: 0.7969 (0.7926)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0490 (0.0429)  loss_giou_unscaled: 0.3860 (0.3848)  cardinality_error_unscaled: 15.5000 (18.6818)  loss_ce_0_unscaled: 0.9727 (0.9492)  loss_bbox_0_unscaled: 0.0317 (0.0359)  loss_giou_0_unscaled: 0.3446 (0.3299)  cardinality_error_0_unscaled: 2.5000 (3.1818)  loss_ce_1_unscaled: 0.7930 (0.7944)  loss_bbox_1_unscaled: 0.0453 (0.0451)  loss_giou_1_unscaled: 0.3769 (0.3840)  cardinality_error_1_unscaled: 3.0000 (3.5000)  loss_ce_enc_unscaled: 0.8164 (0.8423)  loss_bbox_enc_unscaled: 0.0383 (0.0389)  loss_giou_enc_unscaled: 0.3108 (0.3438)  cardinality_error_enc_unscaled: 1.2500 (1.3182)  time: 0.3235  data: 0.0456  max mem: 9336
# Test:  [20/35]  eta: 0:00:04  class_error: 0.00  loss: 7.5505 (7.2795)  loss_ce: 0.8125 (0.8058)  loss_bbox: 0.2308 (0.2251)  loss_giou: 0.8063 (0.7976)  loss_ce_0: 0.9453 (0.9537)  loss_bbox_0: 0.1586 (0.1784)  loss_giou_0: 0.7151 (0.6809)  loss_ce_1: 0.8008 (0.8218)  loss_bbox_1: 0.2265 (0.2213)  loss_giou_1: 0.8165 (0.7885)  loss_ce_enc: 0.8164 (0.8454)  loss_bbox_enc: 0.2153 (0.2087)  loss_giou_enc: 0.7964 (0.7522)  loss_ce_unscaled: 0.8125 (0.8058)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0462 (0.0450)  loss_giou_unscaled: 0.4032 (0.3988)  cardinality_error_unscaled: 15.0000 (17.3690)  loss_ce_0_unscaled: 0.9453 (0.9537)  loss_bbox_0_unscaled: 0.0317 (0.0357)  loss_giou_0_unscaled: 0.3575 (0.3405)  cardinality_error_0_unscaled: 2.5000 (3.4524)  loss_ce_1_unscaled: 0.8008 (0.8218)  loss_bbox_1_unscaled: 0.0453 (0.0443)  loss_giou_1_unscaled: 0.4083 (0.3943)  cardinality_error_1_unscaled: 3.0000 (3.4643)  loss_ce_enc_unscaled: 0.8164 (0.8454)  loss_bbox_enc_unscaled: 0.0431 (0.0417)  loss_giou_enc_unscaled: 0.3982 (0.3761)  cardinality_error_enc_unscaled: 1.2500 (1.2381)  time: 0.2864  data: 0.0219  max mem: 9336
# Test:  [30/35]  eta: 0:00:01  class_error: 0.00  loss: 7.2012 (6.9882)  loss_ce: 0.8125 (0.7915)  loss_bbox: 0.1725 (0.2023)  loss_giou: 0.7534 (0.7446)  loss_ce_0: 0.9219 (0.9380)  loss_bbox_0: 0.1565 (0.1663)  loss_giou_0: 0.6709 (0.6623)  loss_ce_1: 0.8125 (0.8018)  loss_bbox_1: 0.1804 (0.2014)  loss_giou_1: 0.7031 (0.7425)  loss_ce_enc: 0.8203 (0.8306)  loss_bbox_enc: 0.1952 (0.1929)  loss_giou_enc: 0.7053 (0.7141)  loss_ce_unscaled: 0.8125 (0.7915)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0345 (0.0405)  loss_giou_unscaled: 0.3767 (0.3723)  cardinality_error_unscaled: 15.0000 (20.4113)  loss_ce_0_unscaled: 0.9219 (0.9380)  loss_bbox_0_unscaled: 0.0313 (0.0333)  loss_giou_0_unscaled: 0.3354 (0.3311)  cardinality_error_0_unscaled: 2.7500 (3.9194)  loss_ce_1_unscaled: 0.8125 (0.8018)  loss_bbox_1_unscaled: 0.0361 (0.0403)  loss_giou_1_unscaled: 0.3515 (0.3712)  cardinality_error_1_unscaled: 3.2500 (4.1371)  loss_ce_enc_unscaled: 0.8203 (0.8306)  loss_bbox_enc_unscaled: 0.0390 (0.0386)  loss_giou_enc_unscaled: 0.3527 (0.3570)  cardinality_error_enc_unscaled: 1.0000 (1.2177)  time: 0.2782  data: 0.0204  max mem: 9336
# Test:  [34/35]  eta: 0:00:00  class_error: 0.00  loss: 6.3670 (6.9551)  loss_ce: 0.8125 (0.7926)  loss_bbox: 0.1515 (0.1955)  loss_giou: 0.6705 (0.7384)  loss_ce_0: 0.9180 (0.9335)  loss_bbox_0: 0.1378 (0.1634)  loss_giou_0: 0.6749 (0.6671)  loss_ce_1: 0.8047 (0.8008)  loss_bbox_1: 0.1525 (0.1943)  loss_giou_1: 0.6794 (0.7371)  loss_ce_enc: 0.8125 (0.8294)  loss_bbox_enc: 0.1592 (0.1887)  loss_giou_enc: 0.6859 (0.7143)  loss_ce_unscaled: 0.8125 (0.7926)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0303 (0.0391)  loss_giou_unscaled: 0.3353 (0.3692)  cardinality_error_unscaled: 17.7500 (20.2857)  loss_ce_0_unscaled: 0.9180 (0.9335)  loss_bbox_0_unscaled: 0.0276 (0.0327)  loss_giou_0_unscaled: 0.3374 (0.3336)  cardinality_error_0_unscaled: 3.0000 (3.7833)  loss_ce_1_unscaled: 0.8047 (0.8008)  loss_bbox_1_unscaled: 0.0305 (0.0389)  loss_giou_1_unscaled: 0.3397 (0.3686)  cardinality_error_1_unscaled: 3.2500 (3.9310)  loss_ce_enc_unscaled: 0.8125 (0.8294)  loss_bbox_enc_unscaled: 0.0318 (0.0377)  loss_giou_enc_unscaled: 0.3430 (0.3571)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.2955  data: 0.0183  max mem: 9336
# Test: Total time: 0:00:10 (0.3075 s / it)
# Averaged stats: class_error: 0.00  loss: 6.3670 (6.9551)  loss_ce: 0.8125 (0.7926)  loss_bbox: 0.1515 (0.1955)  loss_giou: 0.6705 (0.7384)  loss_ce_0: 0.9180 (0.9335)  loss_bbox_0: 0.1378 (0.1634)  loss_giou_0: 0.6749 (0.6671)  loss_ce_1: 0.8047 (0.8008)  loss_bbox_1: 0.1525 (0.1943)  loss_giou_1: 0.6794 (0.7371)  loss_ce_enc: 0.8125 (0.8294)  loss_bbox_enc: 0.1592 (0.1887)  loss_giou_enc: 0.6859 (0.7143)  loss_ce_unscaled: 0.8125 (0.7926)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0303 (0.0391)  loss_giou_unscaled: 0.3353 (0.3692)  cardinality_error_unscaled: 17.7500 (20.2857)  loss_ce_0_unscaled: 0.9180 (0.9335)  loss_bbox_0_unscaled: 0.0276 (0.0327)  loss_giou_0_unscaled: 0.3374 (0.3336)  cardinality_error_0_unscaled: 3.0000 (3.7833)  loss_ce_1_unscaled: 0.8047 (0.8008)  loss_bbox_1_unscaled: 0.0305 (0.0389)  loss_giou_1_unscaled: 0.3397 (0.3686)  cardinality_error_1_unscaled: 3.2500 (3.9310)  loss_ce_enc_unscaled: 0.8125 (0.8294)  loss_bbox_enc_unscaled: 0.0318 (0.0377)  loss_giou_enc_unscaled: 0.3430 (0.3571)  cardinality_error_enc_unscaled: 1.2500 (1.2500)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.556
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.683
# Test:  [ 0/35]  eta: 0:00:20  class_error: 0.00  loss: 5.9020 (5.9020)  loss_ce: 0.7695 (0.7695)  loss_bbox: 0.1265 (0.1265)  loss_giou: 0.5625 (0.5625)  loss_ce_0: 1.0938 (1.0938)  loss_bbox_0: 0.1074 (0.1074)  loss_giou_0: 0.4311 (0.4311)  loss_ce_1: 0.7305 (0.7305)  loss_bbox_1: 0.1354 (0.1354)  loss_giou_1: 0.5800 (0.5800)  loss_ce_enc: 0.7812 (0.7812)  loss_bbox_enc: 0.1083 (0.1083)  loss_giou_enc: 0.4759 (0.4759)  loss_ce_unscaled: 0.7695 (0.7695)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0253 (0.0253)  loss_giou_unscaled: 0.2812 (0.2812)  cardinality_error_unscaled: 0.7500 (0.7500)  loss_ce_0_unscaled: 1.0938 (1.0938)  loss_bbox_0_unscaled: 0.0215 (0.0215)  loss_giou_0_unscaled: 0.2156 (0.2156)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.7305 (0.7305)  loss_bbox_1_unscaled: 0.0271 (0.0271)  loss_giou_1_unscaled: 0.2900 (0.2900)  cardinality_error_1_unscaled: 1.2500 (1.2500)  loss_ce_enc_unscaled: 0.7812 (0.7812)  loss_bbox_enc_unscaled: 0.0217 (0.0217)  loss_giou_enc_unscaled: 0.2380 (0.2380)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.5843  data: 0.2903  max mem: 9336
# Test:  [10/35]  eta: 0:00:07  class_error: 0.00  loss: 7.4423 (7.0463)  loss_ce: 0.7812 (0.7617)  loss_bbox: 0.2465 (0.2147)  loss_giou: 0.8229 (0.7909)  loss_ce_0: 1.0391 (1.0071)  loss_bbox_0: 0.1729 (0.1670)  loss_giou_0: 0.5969 (0.6089)  loss_ce_1: 0.7969 (0.7749)  loss_bbox_1: 0.2431 (0.2143)  loss_giou_1: 0.7393 (0.7686)  loss_ce_enc: 0.7812 (0.8015)  loss_bbox_enc: 0.2351 (0.2055)  loss_giou_enc: 0.7601 (0.7311)  loss_ce_unscaled: 0.7812 (0.7617)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0493 (0.0429)  loss_giou_unscaled: 0.4115 (0.3954)  cardinality_error_unscaled: 8.0000 (10.6591)  loss_ce_0_unscaled: 1.0391 (1.0071)  loss_bbox_0_unscaled: 0.0346 (0.0334)  loss_giou_0_unscaled: 0.2985 (0.3045)  cardinality_error_0_unscaled: 1.2500 (1.2273)  loss_ce_1_unscaled: 0.7969 (0.7749)  loss_bbox_1_unscaled: 0.0486 (0.0429)  loss_giou_1_unscaled: 0.3696 (0.3843)  cardinality_error_1_unscaled: 1.5000 (1.8864)  loss_ce_enc_unscaled: 0.7812 (0.8015)  loss_bbox_enc_unscaled: 0.0470 (0.0411)  loss_giou_enc_unscaled: 0.3800 (0.3656)  cardinality_error_enc_unscaled: 1.2500 (1.3182)  time: 0.3100  data: 0.0434  max mem: 9336
# Test:  [20/35]  eta: 0:00:04  class_error: 0.00  loss: 7.1395 (7.0917)  loss_ce: 0.7812 (0.7818)  loss_bbox: 0.2085 (0.2078)  loss_giou: 0.8088 (0.7774)  loss_ce_0: 0.9922 (0.9989)  loss_bbox_0: 0.1729 (0.1656)  loss_giou_0: 0.6152 (0.6211)  loss_ce_1: 0.7969 (0.7904)  loss_bbox_1: 0.2048 (0.2086)  loss_giou_1: 0.7738 (0.7670)  loss_ce_enc: 0.7891 (0.8211)  loss_bbox_enc: 0.1909 (0.2032)  loss_giou_enc: 0.7628 (0.7487)  loss_ce_unscaled: 0.7812 (0.7818)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0417 (0.0416)  loss_giou_unscaled: 0.4044 (0.3887)  cardinality_error_unscaled: 8.0000 (9.8571)  loss_ce_0_unscaled: 0.9922 (0.9989)  loss_bbox_0_unscaled: 0.0346 (0.0331)  loss_giou_0_unscaled: 0.3076 (0.3106)  cardinality_error_0_unscaled: 1.2500 (1.2262)  loss_ce_1_unscaled: 0.7969 (0.7904)  loss_bbox_1_unscaled: 0.0410 (0.0417)  loss_giou_1_unscaled: 0.3869 (0.3835)  cardinality_error_1_unscaled: 1.2500 (1.7262)  loss_ce_enc_unscaled: 0.7891 (0.8211)  loss_bbox_enc_unscaled: 0.0382 (0.0406)  loss_giou_enc_unscaled: 0.3814 (0.3744)  cardinality_error_enc_unscaled: 1.2500 (1.2381)  time: 0.2955  data: 0.0219  max mem: 9336
# Test:  [30/35]  eta: 0:00:01  class_error: 0.00  loss: 6.6911 (6.8755)  loss_ce: 0.7617 (0.7663)  loss_bbox: 0.1561 (0.1902)  loss_giou: 0.6589 (0.7424)  loss_ce_0: 0.9648 (0.9817)  loss_bbox_0: 0.1325 (0.1587)  loss_giou_0: 0.5684 (0.6278)  loss_ce_1: 0.7617 (0.7731)  loss_bbox_1: 0.1525 (0.1908)  loss_giou_1: 0.6451 (0.7333)  loss_ce_enc: 0.7617 (0.7956)  loss_bbox_enc: 0.1529 (0.1893)  loss_giou_enc: 0.6260 (0.7263)  loss_ce_unscaled: 0.7617 (0.7663)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0312 (0.0380)  loss_giou_unscaled: 0.3295 (0.3712)  cardinality_error_unscaled: 7.7500 (11.8710)  loss_ce_0_unscaled: 0.9648 (0.9817)  loss_bbox_0_unscaled: 0.0265 (0.0317)  loss_giou_0_unscaled: 0.2842 (0.3139)  cardinality_error_0_unscaled: 1.0000 (1.2177)  loss_ce_1_unscaled: 0.7617 (0.7731)  loss_bbox_1_unscaled: 0.0305 (0.0382)  loss_giou_1_unscaled: 0.3225 (0.3667)  cardinality_error_1_unscaled: 1.2500 (2.2339)  loss_ce_enc_unscaled: 0.7617 (0.7956)  loss_bbox_enc_unscaled: 0.0306 (0.0379)  loss_giou_enc_unscaled: 0.3130 (0.3631)  cardinality_error_enc_unscaled: 1.0000 (1.2177)  time: 0.2970  data: 0.0223  max mem: 9336
# Test:  [34/35]  eta: 0:00:00  class_error: 0.00  loss: 6.1606 (6.8590)  loss_ce: 0.7656 (0.7684)  loss_bbox: 0.1455 (0.1839)  loss_giou: 0.6538 (0.7377)  loss_ce_0: 0.9570 (0.9777)  loss_bbox_0: 0.1316 (0.1578)  loss_giou_0: 0.6138 (0.6349)  loss_ce_1: 0.7539 (0.7772)  loss_bbox_1: 0.1255 (0.1845)  loss_giou_1: 0.6330 (0.7296)  loss_ce_enc: 0.7578 (0.7961)  loss_bbox_enc: 0.1341 (0.1851)  loss_giou_enc: 0.6370 (0.7262)  loss_ce_unscaled: 0.7656 (0.7684)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0291 (0.0368)  loss_giou_unscaled: 0.3269 (0.3688)  cardinality_error_unscaled: 9.0000 (11.2595)  loss_ce_0_unscaled: 0.9570 (0.9777)  loss_bbox_0_unscaled: 0.0263 (0.0316)  loss_giou_0_unscaled: 0.3069 (0.3174)  cardinality_error_0_unscaled: 1.2500 (1.2690)  loss_ce_1_unscaled: 0.7539 (0.7772)  loss_bbox_1_unscaled: 0.0251 (0.0369)  loss_giou_1_unscaled: 0.3165 (0.3648)  cardinality_error_1_unscaled: 1.5000 (2.1381)  loss_ce_enc_unscaled: 0.7578 (0.7961)  loss_bbox_enc_unscaled: 0.0268 (0.0370)  loss_giou_enc_unscaled: 0.3185 (0.3631)  cardinality_error_enc_unscaled: 1.2500 (1.2500)  time: 0.2878  data: 0.0210  max mem: 9336
# Test: Total time: 0:00:10 (0.3000 s / it)
# Averaged stats: class_error: 0.00  loss: 6.1606 (6.8590)  loss_ce: 0.7656 (0.7684)  loss_bbox: 0.1455 (0.1839)  loss_giou: 0.6538 (0.7377)  loss_ce_0: 0.9570 (0.9777)  loss_bbox_0: 0.1316 (0.1578)  loss_giou_0: 0.6138 (0.6349)  loss_ce_1: 0.7539 (0.7772)  loss_bbox_1: 0.1255 (0.1845)  loss_giou_1: 0.6330 (0.7296)  loss_ce_enc: 0.7578 (0.7961)  loss_bbox_enc: 0.1341 (0.1851)  loss_giou_enc: 0.6370 (0.7262)  loss_ce_unscaled: 0.7656 (0.7684)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0291 (0.0368)  loss_giou_unscaled: 0.3269 (0.3688)  cardinality_error_unscaled: 9.0000 (11.2595)  loss_ce_0_unscaled: 0.9570 (0.9777)  loss_bbox_0_unscaled: 0.0263 (0.0316)  loss_giou_0_unscaled: 0.3069 (0.3174)  cardinality_error_0_unscaled: 1.2500 (1.2690)  loss_ce_1_unscaled: 0.7539 (0.7772)  loss_bbox_1_unscaled: 0.0251 (0.0369)  loss_giou_1_unscaled: 0.3165 (0.3648)  cardinality_error_1_unscaled: 1.5000 (2.1381)  loss_ce_enc_unscaled: 0.7578 (0.7961)  loss_bbox_enc_unscaled: 0.0268 (0.0370)  loss_giou_enc_unscaled: 0.3185 (0.3631)  cardinality_error_enc_unscaled: 1.2500 (1.2500)
# Accumulating evaluation results...
# DONE (t=0.11s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.602
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.725
# Training time 1:01:06
# Results saved to output/results.json
# Results saved to output/metrics_plot.png

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

plt.figure(figsize=(12, 8))

plt.plot(
    df['epoch'],
    df['train_loss'],
    label='Training Loss',
    marker='o',
    linestyle='-'
)

plt.plot(
    df['epoch'],
    df['test_loss'],
    label='Validation Loss',
    marker='o',
    linestyle='--'
)

plt.title('Train/Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

df['avg_precision'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[0])
df['avg_recall'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[6])

plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_precision'],
    marker='o',
    linestyle='-'
)
plt.title('AP (IoU=0.50:0.95, area=all, maxDets=100) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AP')
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_recall'],
    marker='o',
    linestyle='-'
)
plt.title('AR (IoU=0.50:0.95, area=all, maxDets=1) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AR')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Run inference with fine-tuned model

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[20]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(thickness=thickness)
label_annotator = sv.LabelAnnotator(
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    text_thickness=thickness,
    smart_position=True)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
import supervision as sv
from rfdetr import RFDETRBase
from PIL import Image

detections_images = []

for i in range(16):
    path, image, annotations = ds[i]
    image = Image.open(path)

    detections = model.predict(image, threshold=0.5)

    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
    thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

    bbox_annotator = sv.BoxAnnotator(thickness=thickness)
    label_annotator = sv.LabelAnnotator(
        text_color=sv.Color.BLACK,
        text_scale=text_scale,
        text_thickness=thickness,
        smart_position=True)

    detections_labels = [
        f"{ds.classes[class_id]} {confidence:.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    detections_image = image.copy()
    detections_image = bbox_annotator.annotate(detections_image, detections)
    detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

    detections_images.append(detections_image)

sv.plot_images_grid(images=detections_images, grid_size=(4, 4))

# %% [markdown]
# ## Evaluate fine-tuned model

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0.5)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 71/71 [00:03<00:00, 21.67it/s]

# %%
import random
import numpy as np
from tqdm import tqdm
from PIL import Image
import supervision as sv
from supervision import box_iou_batch

NUM_IMAGES = 16
all_ious = []


dataset_samples = list(ds)
random.shuffle(dataset_samples)
selected_samples = dataset_samples[:NUM_IMAGES]


print(f"Processing {NUM_IMAGES} random images and calculating IoUs...")
for path, image, annotations in tqdm(selected_samples):
    detections = model.predict(image)
    gt_classes = np.unique(annotations.class_id) if len(annotations) > 0 else []

    for class_id in gt_classes:
        gt_detections_cls = annotations[annotations.class_id == class_id]
        pred_detections_cls = detections[detections.class_id == class_id]

        if len(gt_detections_cls) == 0 or len(pred_detections_cls) == 0:
            continue

        gt_boxes = gt_detections_cls.xyxy
        pred_boxes = pred_detections_cls.xyxy
        iou_matrix = box_iou_batch(gt_boxes, pred_boxes)
        all_ious.extend(iou_matrix.flatten())

if len(all_ious) > 0:
    average_all_iou = np.mean(all_ious)
    print(f"\nAverage IoU for all detections: {average_all_iou:.4f}")
else:
    print("No IoUs calculated.")
# Out:
# Processing 16 random images and calculating IoUs...
# 100%|██████████| 16/16 [00:00<00:00, 21.10it/s]
# Average IoU for all detections: 0.4793

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()

map_result.plot()
